# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import cv2
# Out:
# /home/mech-user/.virtualenvs/cv/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
camera = cv2.VideoCapture(0)
while True:
    retval, im = camera.read()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.bilateralFilter(gray, 11, 17, 17)
    edged = cv2.Canny(gray2,30, 40)
    plt.imshow(edged, cmap='gray')
    cv2.waitKey(10)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (10, 10))
closed = cv2.morphologyEx(edged, cv2.MORPH_CLOSE, kernel)
plt.imshow(closed)
#(_, cnts, _) = cv2.findContours(mask.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#c = max(cnts, key=cv2.contourArea)

# %%
mask = cv2.inRange(im, np.array([0,0,0]), np.array([255,255,255]))
mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
peri = cv2.arcLength(c, True)
approx = cv2.approxPolyDP(c, 0.05* peri, True)
img = im.copy()
cv2.drawContours(img, [approx], -1, (0,255, 0), 4)
plt.imshow(img)
